# %% [markdown]
# ### Customer Retention

# %% [markdown]
# Problem description:
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %% [markdown]
# #### Let's start with loading the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="ticks", color_codes=True)

# %%
# df=pd.read_excel('customer_retention_codesheet.xlsx')
# dfs=pd.read_excel('customer_retention_datasheet.xlsx')
df=pd.read_excel('customer_retention_dataset.xlsx')

# %%
#
pd.set_option('display.max_columns',None)

# %%
df.head()
# Out:
#   Gender of respondent How old are you?  Which city do you shop online from?  \
# 0                 Male       31-40 years                               Delhi
# 1               Female       21-30 years                               Delhi
# 2               Female       21-30 years                       Greater Noida
# 3                 Male       21-30 years                             Karnal
# 4               Female       21-30 years                          Bangalore
#
#    What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   Since How Long You are Shopping Online ?  \
# 0                            Above 4 years
# 1                            Above 4 years
# 2                                3-4 years
# ...

# %%
df.columns
# Out:
# Index(['Gender of respondent', 'How old are you? ',
#        'Which city do you shop online from?',
#        'What is the Pin Code of where you shop online from?',
#        'Since How Long You are Shopping Online ?',
#        'How many times you have made an online purchase in the past 1 year?',
#        'How do you access the internet while shopping on-line?',
#        'Which device do you use to access the online shopping?',
#        'What is the screen size of your mobile device?',
#        'What is the operating system (OS) of your device?',
#        'What browser do you run on your device to access the website?',
#        'Which channel did you follow to arrive at your favorite online store for the first time?',
#        'After first visit, how do you reach the online retail store?',
#        'How much time do you explore the e- retail store before making a purchase decision?',
#        'What is your preferred payment Option?',
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# Total 269 rows and 71 columns in the dataset.

# %%
# checking null value
df.isnull().sum()
# Out:
# Gender of respondent                                                    0
# How old are you?                                                        0
# Which city do you shop online from?                                     0
# What is the Pin Code of where you shop online from?                     0
# Since How Long You are Shopping Online ?                                0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.describe()
# Out:
#        What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                     --------------  -----
#  0   Gender of respondent                                                                                       269 non-null    object
#  1   How old are you?                                                                                           269 non-null    object
#  2   Which city do you shop online from?                                                                        269 non-null    object
#  3   What is the Pin Code of where you shop online from?                                                        269 non-null    int64
# ...

# %%
sns.catplot(x='Gender of respondent', y='How old are you? ',data=df)
plt.show()

# %% [markdown]
# Obeservation:
#
#     1. Male whose age is 51 years and above do less online shoping.
#     2. Male who is less than 20 years seems to do less online shoping.

# %% [markdown]
# #### Which city do you shop online from?

# %%
sns.catplot(x='Which city do you shop online from?',kind='count',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Obeservation:
#
#     Delhi people do more online shoping.

# %% [markdown]
# #### Since How Long You are Shopping Online ?

# %%
sns.catplot(x='Since How Long You are Shopping Online ?',kind='count',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Obesrvation:
#
#     Number of people who do online shoping above 4 years is more than others

# %% [markdown]
# #### How many times you have made an online purchase in the past 1 year?

# %%
fs=df['How many times you have made an online purchase in the past 1 year?'].value_counts()
fig,ax=plt.subplots()
ax.pie(fs.values,labels=fs.index,autopct='%.0f%%')
ax.set_title('How many times you have made an online purchase in the past 1 year?')
plt.show()

# %% [markdown]
# Obeservation:
#
#     1. 42% people who did less time shopping.
#     2. Only 2% percentage people who did highest time shopping.

# %%
sns.countplot(x='How many times you have made an online purchase in the past 1 year?',hue='How old are you? ',data=df)
plt.xticks(rotation='vertical')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# #### How many times you have made an online purchase in the past 1 year?

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(15,10))
ax=sns.countplot(x='How many times you have made an online purchase in the past 1 year?',hue='Gender of respondent', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# from above chart, it seems, female do less shoping than the male.

# %% [markdown]
# ### How do you access the internet while shopping on-line?

# %%
plt.figure(figsize=(18,12))
sns.set_theme(style="darkgrid")
ax=sns.countplot(x='How do you access the internet while shopping on-line?',hue='Which device do you use to access the online shopping?', data=df)
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Observation:
#
#     Most of the People prefer smartphone as device and mobile internet for the internet access.

# %% [markdown]
# ### What is the screen size of your mobile device?

# %%
sns.countplot(x='What is the screen size of your mobile device?',hue='Gender of respondent',data=df)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Obeservation:
#
#     Most Female mobile device screen size is 5.5 inches.
#     Most male mobile device screen size is unknown.

# %% [markdown]
# ### What is the operating system (OS) of your device?

# %%
sns.countplot(x='What is the operating system (OS) of your device?',hue='Gender of respondent',data=df)
plt.show()

# %% [markdown]
# Observation:
#
#     Most of male and female prefer Window/windows Mobile as operating system

# %% [markdown]
# ### What browser do you run on your device to access the website?

# %%
sns.countplot(x='What browser do you run on your device to access the website?',hue='Gender of respondent',data=df)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Both Male and female prefer Google chrome as Browser

# %% [markdown]
# ### Which channel did you follow to arrive at your favorite online store for the first time?

# %%
preferedchannel=df['Which channel did you follow to arrive at your favorite online store for the first time?'].value_counts()
sns.catplot(x=preferedchannel.index,y=preferedchannel.values,kind='bar',data=df)
plt.show()

# %% [markdown]
# Most People arrive thier favourite online store for the first time via search engine.

# %% [markdown]
# ### After first visit, how do you reach the online retail store?

# %%
sns.countplot(x='After first visit, how do you reach the online retail store?',hue='Gender of respondent',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Obesrvation:
#
#     1. Most of the male prefer the search engine to reach the online retail store after fisrt vist.
#     2. Most of the woman prefer application to reach online retail store after first visit.

# %% [markdown]
# ### How much time do you explore the e- retail store before making a purchase decision?

# %%
sns.countplot(x='How much time do you explore the e- retail store before making a purchase decision?',hue='Gender of respondent',data=df)
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# Observation:
#
#     Most of the male takes 6-10 mins time before making a purchase decision.
#     Most of the female takes more than 15 mins time to make a purchase decision.

# %% [markdown]
# ### What is your preferred payment Option?

# %%
sns.countplot(x='What is your preferred payment Option?',hue='Gender of respondent',data=df)
plt.xticks(rotation=25)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Observation:
#
#     Most of the male and female prefer Credit/Debit cards as payment option.

# %% [markdown]
# ### How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?

# %%
sns.countplot(x='How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?',data=df)
plt.show()

# %% [markdown]
# Observation:
#
#     Most of people, sometimes abandom the shopping cart.

# %%
sns.countplot(x='Why did you abandon the “Bag”, “Shopping Cart”?',data=df)
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# Most of people abandon the bag because of the promo code not applicable.

# %%
sns.countplot(x='The content on the website must be easy to read and understand',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Most of the people prefer e-shoping website which is  easy to read and understand.

# %%
sns.countplot(x='Information on similar product to the one highlighted  is important for product comparison',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='Which of the Indian online retailer would you recommend to a friend?',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Obeservation:
#
#     amazon.in is most recommended by the people.

# %%
sns.countplot(x='Website is as efficient as before',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Obesrvation:
#
#     amazon.in seems as efficient as before.

# %%
sns.countplot(x='Frequent disruption when moving from one page to another',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Obeservation:
#
#     Amazon.in has more frequent disruption when moving from one page to another.

# %%
sns.countplot(x='Longer delivery period',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Obesrvation:
#
#     Shorter delivery period = myntra.com
#     Longer delivery period = paytm.com
#
#     People would prefer whose delivery period is short.

# %%
sns.countplot(x='Change in website/Application design',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation:
#
#     amazon.in has more change in website/application design.

# %%
sns.countplot(x='Limited mode of payment on most products (promotion, sales period)',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation:
#
#     People would go for those e-shoping sites  who accept every mode of payment.
#     Here amazon and snapdeal have more limited mode of payment on most products.

# %%
sns.countplot(x='From the following, tick any (or all) of the online retailers you have shopped from;',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Obesrvation:
#
#     most of the people do shoping from all the e-shoping sites.

# %%
sns.countplot(x='All relevant information on listed products must be stated clearly',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation:
#
#     from above chart, people prefer that e-shoping sites where all relevent information on listed products must be stated clearly.

# %%
plt.figure(figsize=(15,15)),
sns.countplot(x='Longer page loading time (promotion, sales period)',hue='Which device do you use to access the online shopping?',data=df)
plt.xticks(rotation='vertical')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Observatio:
#
#     smartphone user facing the longer page loading time(promotion, sales period)

# %%
plt.figure(figsize=(15,15)),
sns.countplot(x='Longer time to get logged in (promotion, sales period)',hue='Which device do you use to access the online shopping?',data=df)
plt.xticks(rotation='vertical')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Observation:
#
#     Most of the sites have longer time to get logged when people log in through the smartphone.

# %%
sns.countplot(x='Perceived Trustworthiness',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation:
#
#     Amazon has gained trustworthiness

# %%
sns.countplot(x='Perceived Trustworthiness',hue='Gender of respondent',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation:
#
#         Female perceived trustworthines on Amazon.in
#         Male have perceived trustworhines on amazon,flipkart and snapdeal

# %%
sns.countplot(x='Wild variety of product on offer',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation:
#
#     Only amazon.in and flipkart.com have wild variety of product on offer.

# %% [markdown]
# ### User satisfaction cannot exist without trust

# %%
sns.countplot(x='User satisfaction cannot exist without trust',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Quickness to complete purchase

# %%
sns.countplot(x='Quickness to complete purchase',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Shopping online is convenient and flexible

# %%
sns.countplot(x='Shopping online is convenient and flexible',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Most of people do agree that shopping online is convenient and flexible.

# %% [markdown]
# ### Enjoyment is derived from shopping online

# %%
sns.countplot(x='Enjoyment is derived from shopping online',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Loading and processing speed

# %%
sns.countplot(x='Loading and processing speed',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Speedy order delivery

# %%
sns.countplot(x='Speedy order delivery ',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Fast loading website speed of website and application

# %%
sns.countplot(x='Fast loading website speed of website and application',hue='Which of the Indian online retailer would you recommend to a friend?',data=df)
plt.xticks(rotation='vertical')
plt.legend(loc='upper right', bbox_to_anchor=(1,1.7))
plt.show()

# %% [markdown]
# ### Return and replacement policy of the e-tailer is important for purchase decision

# %%
sns.countplot(x='Return and replacement policy of the e-tailer is important for purchase decision',data=df)
# Out:
# <AxesSubplot:xlabel='Return and replacement policy of the e-tailer is important for purchase decision', ylabel='count'>

# %% [markdown]
# ### User friendly Interface of the website

# %%
sns.countplot(x='User friendly Interface of the website',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Convenient Payment methods

# %%
sns.countplot(x='Convenient Payment methods',data=df)
# Out:
# <AxesSubplot:xlabel='Convenient Payment methods', ylabel='count'>

# %% [markdown]
# ### Being able to guarantee the privacy of the customer

# %%
sns.countplot(x='Being able to guarantee the privacy of the customer',data=df)
sns.
# Out:
# <AxesSubplot:xlabel='Being able to guarantee the privacy of the customer', ylabel='count'>

# %% [markdown]
# ### Shopping on the website helps you fulfill certain roles

# %%
sns.countplot(x='Shopping on the website helps you fulfill certain roles',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Shopping on the website helps you fulfill certain roles

# %%
sns.countplot(x='Shopping on the website helps you fulfill certain roles',hue='Gender of respondent',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation:
#
#     Most of the female agree on that shoping on the website helps you fulfill certain roles indifferent.
#     Most of the male agree that shoping on the website helps you fulfill certain roles.

# %% [markdown]
# ### Late declaration of price (promotion, sales period)

# %%
sns.countplot(x='Late declaration of price (promotion, sales period)',data=df)
plt.xticks(rotation='vertical')
plt.show()
